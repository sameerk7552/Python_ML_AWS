# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerk7552/Python_ML_AWS/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20

sum = a + b

print("Sum =", sum)
# Out:
# Sum = 30

# %%
a = 5
b = 3

print("Sum =", a + b)
# Out:
# Sum = 8

# %%
# square of number
num = 4

print("Square =", num * num)
# Out:
# Square = 16

# %%
a = int(input("First number: "))
b = int(input("Second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# First number: 5
# Second number: 7
# Addition = 12
# Subtraction = -2
# Multiplication = 35
# Division = 0.7142857142857143

# %%
#SIMPLE ASSIGNMENT
a = 10
print(a)
# Out:
# 10

# %%
a = 10
a += 5      # a = a + 5
print(a)
# Out:
# 15

# %%
a = 10
a -= 3      # a = a - 3
print(a)
# Out:
# 7

# %%
a = 10
a *= 2      # a = a * 2
print(a)
# Out:
# 20

# %%
a = 10
a /= 2      # a = a / 2
print(a)
# Out:
# 5.0

# %%
a = 10

a += 5
print("+= :", a)

a -= 2
print("-= :", a)

a *= 3
print("*= :", a)

a /= 2
print("/= :", a)

a //= 2
print("//= :", a)

a %= 3
print("%= :", a)

a **= 2
print("**= :", a)
# Out:
# += : 15
# -= : 13
# *= : 39
# /= : 19.5
# //= : 9.0
# %= : 0.0
# **= : 0.0
