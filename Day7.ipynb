# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerk7552/Python_ML_AWS/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#file handling
#read
# update

print("hello")
# Out:
# hello

# %%
from google.colab import drive
#drive.mount('/content/drive')

data = open("/content/drive/MyDrive/hello.txt","r")
data.read()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'hello Sameer!'

# %%
#read
data2 = open("/content/drive/MyDrive/hello.txt","w")
data2.write("Where are you from?")

data2 = open("/content/drive/MyDrive/hello.txt","r")
data2.read()

#for append
data2 = open("/content/drive/MyDrive/hello.txt","a")
data2.write("I am from bihar")

data2 = open("/content/drive/MyDrive/hello.txt","r")
data2.read()
# Out:
# 'Where are you from?I am from bihar'

# %%
# dtrect access without drive

data = open("hello.txt","r")
data.read()
# Out:
# 'hello Sameer!'

# %%
# direct acccess csv file
data1 = open("file1.csv","r")
data.read()

# write and append
# Out:
# ''
