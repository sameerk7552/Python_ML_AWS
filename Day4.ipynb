# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerk7552/Python_ML_AWS/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while (True):
  num = int(input("Enter a num:"))

  if num == 10:
    print(f"num {num} is match")
    break
# Out:
# Enter a num:5
# Enter a num:7
# Enter a num:10
# num 10 is match

# %%
# using while

d = {'users':{'aryans':['raj','nikhil','vineet']}}
i = 0
while i< len(d['users']['aryans']):
  print(d['users']['aryans'][i])
  i += 1
# Out:
# raj
# nikhil
# vineet

# %%
# function calculator
def calculator(a, b, op):
    if op == "+":
        print("Result =", a + b)
    elif op == "-":
        print("Result =", a - b)
    elif op == "*":
        print("Result =", a * b)
    elif op == "/":
        print("Result =", a / b)
    else:
        print("Invalid Operator")

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Choose Operation: +  -  *  /")
op = input("Enter operator: ")

calculator(a, b, op)
# Out:
# Enter first number: 7
# Enter second number: 90
# Choose Operation: +  -  *  /
# Enter operator: +
# Result = 97

# %%
# expection handling -> try,except,final
try:
  print("try part")
except:
  print("except part")
# Out:
# try part

# %%
try:
  print("try part")
  print("hello" + 10)
except:
  print("expect part")
# Out:
# try part
# expect part

# %%
try:
  print(10/0)

except TypeError:
  print("typr error")
except ZeroDivisionError:
  print("zero division error")
# Out:
# zero division error

# %%
try:
  print("try part")
  print(10/0)
except:
  print("except part")
finally:
  print("finally part")
# Out:
# try part
# except part
# finally part

# %%
#lambda
add = lambda x,y:x+y
add(10,29)

cal = lambda *a:eval(f"{a[0]}{a[-1]}{a[1]}")
cal(10,20,"*")
# Out:
# 200

# %%
# list comprehension
print([ i for i in range(5)])

# 2 table list comprehension

num=int(input("enter a number"))
print([num*i for i in range(1,11)])
# Out:
# [0, 1, 2, 3, 4]
# enter a number11
# [11, 22, 33, 44, 55, 66, 77, 88, 99, 110]
